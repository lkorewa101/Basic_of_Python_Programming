# %% [markdown]
# 21113038 고기현

# %%
import time

now = time.time()

sum = 0
for i in range(10000000):
  sum += 1

passed_time = time.time() - now
print(f'계산 소요 시간: {passed_time:.5f}초')
# Out:
# 계산 소요 시간: 1.00409초
