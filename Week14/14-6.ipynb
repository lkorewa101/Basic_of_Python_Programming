# %% [markdown]
# 21113038 고기현

# %%
import math
from random import choices as rdch

for i in range(2, 9):
  trial = pow(10, i)
  expectation = sum(rdch(range(1, 7), k=trial)) / trial
  print(f'{trial:10d}회 시행, 기대값 = {expectation:.6f}')
# Out:
#        100회 시행, 기대값 = 3.290000
#       1000회 시행, 기대값 = 3.585000
#      10000회 시행, 기대값 = 3.518800
#     100000회 시행, 기대값 = 3.510780
#    1000000회 시행, 기대값 = 3.498512
#   10000000회 시행, 기대값 = 3.500420
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-307f95c94d73> in <module>()
#       4 for i in range(2, 9):
#       5   trial = pow(10, i)
# ----> 6   expectation = sum(rdch(range(1, 7), k=trial)) / trial
#       7   print(f'{trial:10d}회 시행, 기대값 = {expectation:.6f}')
#
# /usr/lib/python3.7/random.py in choices(self, population, weights, cum_weights, k)
#     354                 _int = int
#     355                 total = len(population)
# --> 356                 return [population[_int(random() * total)] for i in range(k)]
#     357             cum_weights = list(_itertools.accumulate(weights))
#     358         elif weights is not None:
#
# ...
