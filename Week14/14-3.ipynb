# %% [markdown]
# 21113038 고기현

# %%
from datetime import datetime

now = datetime.now()

# %%
print(now.strftime('%y-%m-%d %H:%M:%S %A'))
print(now.strftime('%Y년 %m월 %d일 %M시 %M분 %S초'))
# Out:
# 21-06-01 05:37:47 Tuesday
# 2021년 06월 01일 37시 37분 47초
