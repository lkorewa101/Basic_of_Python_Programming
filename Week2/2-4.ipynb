# %% [markdown]
# 21113038 고기현

# %%
ch_1 = input("휴대전화 국번호를 입력하시오.")
ch_2 = input("휴대전화 앞번호를 입력하시오.")
ch_3 = input("휴대전화 뒷번호를 입력하시오.")
# Out:
# 휴대전화 국번호를 입력하시오.010
# 휴대전화 앞번호를 입력하시오.1234
# 휴대전화 뒷번호를 입력하시오.1111

# %%
print(ch_1,ch_2,ch_3 , sep="-")
# Out:
# 010-1234-1111
