# %% [markdown]
# 21113038 고기현

# %%
Math = int(input("수학 성적을 입력하시오: "))
Sci = int(input("과학 성적을 입력하시오: "))
Eng = int(input("영어 성적을 입력하시오: "))
# Out:
# 수학 성적을 입력하시오: 95
# 과학 성적을 입력하시오: 80
# 영어 성적을 입력하시오: 95

# %%
sum = (Math+Sci+Eng)
print("합계 점수 = ", sum)
# Out:
# 합계 점수 =  270

# %%
avg = sum / 3
print("평균 점수 = ", avg)
# Out:
# 평균 점수 =  90.0
