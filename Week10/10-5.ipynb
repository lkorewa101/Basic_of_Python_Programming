# %% [markdown]
# 21113038 고기현

# %%
start = int(input("시작 정수값을 입력하시오: "))
end = int(input("끝 정수값을 입력하시오: "))
i = start
while i < end+1:
  print(i)
  i += 1
# Out:
# 시작 정수값을 입력하시오: 1
# 끝 정수값을 입력하시오: 5
# 1
# 2
# 3
# 4
# 5
