# %% [markdown]
# 21113038 고기현

# %%
# 문제 (1)
for a in range(6, 11):
  for b in range(2):
    print("안녕")
# Out:
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕

# %%
# 문제 (2)
for a in range(16, 18):
  for b in range(10, 15):
    print("안녕")
# Out:
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
# 안녕
