# %% [markdown]
# 21113038 고기현

# %%
a = int(input())
b = int(input())

y = 0

if a > 0:
  y += 1
else:
  print("안녕 철수!")

if y > 10:
  print(y + 5)

y += 1
if y <= 0:
  print(y + 12)
# Out:
# -1
# -1
# 안녕 철수!
