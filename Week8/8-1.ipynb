# %% [markdown]
# 21113038 고기현

# %%
x = int(input())
y = int(input())
if x < 20:
  if y == 1:
    x = x % 3
    y = 3
  elif y == 2:
    x = x * 2
    y = 2
  elif y == 3:
    x = x + 3
    y = 2
  else:
    x -= 5
    y += 1
else:
  y = y + 10
print(x, ",", y)
# Out:
# 10
# 3
# 13 , 2
