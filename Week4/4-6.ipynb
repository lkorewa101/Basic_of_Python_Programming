# %% [markdown]
# 21113038 고기현

# %%
myList1 = [100,200]

# %%
myList2 = [300,400]

# %%
myList3 = myList1+myList2

# %%
myList3
# Out:
# [100, 200, 300, 400]

# %%
myList4=[100,200,300]

# %%
myList4*3
# Out:
# [100, 200, 300, 100, 200, 300, 100, 200, 300]

# %%
myList5=[100,200,300]

# %%
len(myList5)
# Out:
# 3
