# %% [markdown]
# 21113038 고기현

# %%
myList = [10, 0, -12, "list","char","100", 50]

# %%
myList[-1]
# Out:
# 50

# %%
myList[:-3]
# Out:
# [10, 0, -12, 'list']

# %%
myList[-2:]
# Out:
# ['100', 50]

# %%
myList[-4:-1]
# Out:
# ['list', 'char', '100']
