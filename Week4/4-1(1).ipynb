# %% [markdown]
# 21113038 고기현

# %%
myList = [10, 0, -12, "list","char","100",50]

# %%
myList[6]
# Out:
# 50

# %%
myList[0:4]
# Out:
# [10, 0, -12, 'list']

# %%
myList[5:]
# Out:
# ['100', 50]

# %%
myList[3:6]
# Out:
# ['list', 'char', '100']
