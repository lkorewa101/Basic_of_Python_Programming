# %% [markdown]
# 21113038 고기현

# %%
myList = []
myList.append(0)
myList.append(10)
myList.append(20)
myList.append(50)
myList.append(30)
myList.append(40)
print(myList)
# Out:
# [0, 10, 20, 50, 30, 40]
