# %% [markdown]
# 21113038 고기현

# %%
myList = [["aaa", "bbb", "ccc", "ddd"], [40,30,20,10]]

# %%
myList[0][1]
# Out:
# 'bbb'

# %%
myList[1][3]
# Out:
# 10

# %%
myList[0][1:3]
# Out:
# ['bbb', 'ccc']

# %%
myList[1][1:]
# Out:
# [30, 20, 10]
