# %% [markdown]
# 21113038 고기현

# %%
myList = [100,200,300]

# %%
myList[1]
# Out:
# 2

# %%
myList
# Out:
# [100, 2, 300]

# %%
myList1 = [100,200,300,400,500]

# %%
del myList1[-1]

# %%
del myList1[2:4]

# %%
del myList1[1:]

# %%
del myList1[:3]

# %%
del myList1[:]
