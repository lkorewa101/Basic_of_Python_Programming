# %% [markdown]
# 21113038 고기현

# %%
seoul = int(input("서울의 온도를 입력하시오: "))
daegu = int(input("대구의 온도를 입력하시오: "))
# Out:
# 서울의 온도를 입력하시오: 29
# 대구의 온도를 입력하시오: 30

# %%
avg = (seoul + daegu) / 2
if avg >= 33:
  print("폭염주의보입니다.")
else:
  print("폭염주의보가 아닙니다.")
# Out:
# 폭염주의보가 아닙니다.
