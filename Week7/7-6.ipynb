# %% [markdown]
# 21113038 고기현

# %%
grade = int(input("점수를 입력하시오: "))
# Out:
# 점수를 입력하시오: 59

# %%
if grade >= 90:
  score = 'A'
elif grade >=80:
  score = 'B'
elif grade >= 70:
  score = 'C'
elif grade >= 60:
  score = 'D'
else:
  score = 'F'

print(score)
# Out:
# F
