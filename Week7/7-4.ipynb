# %% [markdown]
# 21113038 고기현

# %%
x = int(input("정숫값을 입력하시오: "))
# Out:
# 정숫값을 입력하시오: 11

# %%
if  x % 5 == 0:
  print(x, "은/는 5의 배수입니다.")
else:
  print(x, "은/는 5의 배수가 아닙니다.")
# Out:
# 11 은/는 5의 배수가 아닙니다.
