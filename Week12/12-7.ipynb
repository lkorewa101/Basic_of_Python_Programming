# %% [markdown]
# 21113038 고기현

# %%
def stddev(*args):
  def mean():
    return sum(args) / len(args)

  def variance(m):
    total = 0
    for arg in args:
      total += (arg - m) ** 2
    return total / len(args)
  v = variance(mean())
  return v ** 0.5

print('표준편차: ', stddev(1, 2, 3 ,4 ,5))
# Out:
# 표준편차:  1.4142135623730951
