# %% [markdown]
# 21113038 고기현

# %%
def say_hi_to_something(a):
  print(f'HI, {a}.')

func_var = say_hi_to_something

for something in ['Apple', 'Banana', 'Carrot']:
  func_var(something)
# Out:
# HI, Apple.
# HI, Banana.
# HI, Carrot.
