# %% [markdown]
# 21113038 고기현

# %%
# 재귀함수
def factorial_r(n):
  if n == 0:
    return 1
  else :
    return n * factorial_r(n-1)

for i in range(10):
  print(f'{i}! = {factorial_r(i)}')
# Out:
# 0! = 1
# 1! = 1
# 2! = 2
# 3! = 6
# 4! = 24
# 5! = 120
# 6! = 720
# 7! = 5040
# 8! = 40320
# 9! = 362880
