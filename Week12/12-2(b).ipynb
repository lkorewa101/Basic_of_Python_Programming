# %% [markdown]
# 21113038 고기현

# %%
# 반복문

def factorial(n):
  output = 1
  for i in range(1, n+1):
    output *= i

  return output

for i in range(10):
  print(f'{i}! = {factorial(i)}')
# Out:
# 0! = 1
# 1! = 1
# 2! = 2
# 3! = 6
# 4! = 24
# 5! = 120
# 6! = 720
# 7! = 5040
# 8! = 40320
# 9! = 362880
