# %% [markdown]
# 21113038 고기현

# %%
# 반복문으로 피보나치 수열 구하기

def fibo(n):
  a1 = 1
  a2 = 1
  if n == 1:
    output = a1
  elif n == 2:
    output = a2
  else:
    for i in range(1, n-1):
      output = a1 + a2
      a1 = a2
      a2 = output
  return output
print(fibo(6))
# Out:
# 8
