# %% [markdown]
# 컴퓨터소프트웨어학부 고기현

# %%
num1 = float(input("첫번째 실수를 입력하시오: "))
num2 = float(input("두번째 실수를 입력하시오: "))
# Out:
# 첫번째 실수를 입력하시오: 1.41421
# 두번째 실수를 입력하시오: 3.14159

# %%
sum = round(num1 + num2, 3)
print("두 실수의 합은" ,sum, "입니다.")
# Out:
# 두 실수의 합은 4.556 입니다.
