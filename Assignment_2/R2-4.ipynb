# %% [markdown]
# 컴퓨터소프트웨어학부 고기현

# %%
for i in range(-5, 6):
  x = int(input())
  if x == 0:
    print("Zero")
  elif x % 3 == 0:
    print(x, "는 3의 배수입니다.")
  else:
    print(x, "는 3의 배수가 아닙니다.")
  i += 1
# Out:
# 3
# 3 는 3의 배수입니다.
# 1
# 1 는 3의 배수가 아닙니다.
# 3
# 3 는 3의 배수입니다.
# 1
# 1 는 3의 배수가 아닙니다.
# 3
# 3 는 3의 배수입니다.
# 1
# 1 는 3의 배수가 아닙니다.
# 3
# 3 는 3의 배수입니다.
# 1
# 1 는 3의 배수가 아닙니다.
# 3
# 3 는 3의 배수입니다.
# 1
# 1 는 3의 배수가 아닙니다.
# 3
# 3 는 3의 배수입니다.
