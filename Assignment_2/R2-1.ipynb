# %% [markdown]
# 컴퓨터소프트웨어학부 고기현

# %%
num1 = int(input("첫번째 정수를 입력하시오: "))
num2 = int(input("두번째 정수를 입력하시오: "))
# Out:
# 첫번째 정수를 입력하시오: 10
# 두번째 정수를 입력하시오: 20

# %%
if num1 > 0 and num2 > 0:
  print("두 입력값 모두 양수입니다.")
# Out:
# 두 입력값 모두 양수입니다.
