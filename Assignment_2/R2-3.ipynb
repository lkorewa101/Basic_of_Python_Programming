# %% [markdown]
# 컴퓨터소프트웨어학부 고기현

# %%
a = float(input("첫번째 숫자를 입력하시오: "))
b = float(input("두번째 숫자를 입력하시오: "))

y = 0
if a > 0:
  y = y + 5
if a <= 0:
  print("안녕")
  print(str(-1.0 * a))
print(y)
# Out:
# 첫번째 숫자를 입력하시오: -2
# 두번째 숫자를 입력하시오: 5
# 안녕
# 2.0
# 0
