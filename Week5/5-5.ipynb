# %% [markdown]
# 21113038 고기현

# %%
myDict = {"math":90, "English":100, "science":85}
del myDict["math"]
myDict
# Out:
# {'English': 100, 'science': 85}

# %%
myDict.clear()

# %%
myDict={"math":90,"English":100,"science":85}

# %%
myDict["music"]=95
myDict
# Out:
# {'English': 100, 'math': 90, 'music': 95, 'science': 85}

# %%
myDict={"math":90,"English":100,"science":85}
list(myDict.keys())
# Out:
# ['math', 'English', 'science']

# %%
myDict={"math":90,"English":100,"science":85}
list(myDict.values())
# Out:
# [90, 100, 85]

# %%
myDict={"math":90,"English":100,"science":85}
list(myDict.items())
# Out:
# [('math', 90), ('English', 100), ('science', 85)]
