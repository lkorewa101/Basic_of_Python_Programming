# %% [markdown]
# 21113038 고기현

# %%
myT = (50,40,30,20,10,0)

# %%
myT[-1]
# Out:
# 0

# %%
myT[:-2]
# Out:
# (50, 40, 30, 20)

# %%
myT[-4:]
# Out:
# (30, 20, 10, 0)

# %%
myT[-3:-1]
# Out:
# (20, 10)
