# %% [markdown]
# 21113038 고기현

# %%
myTuple = (100,200,300)
del myTuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-69c55a95d431> in <module>()
#       1 myTuple = (100,200,300)
# ----> 2 del myTuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
myTuple = (100,200,300)
myTuple[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-06bff85686a3> in <module>()
#       1 myTuple = (100,200,300)
# ----> 2 myTuple[0] = 10
#
# TypeError: 'tuple' object does not support item assignment
