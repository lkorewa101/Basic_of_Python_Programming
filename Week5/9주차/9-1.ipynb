# %% [markdown]
# 21113038 고기현

# %%
# 문제 (1)
for i in range(10,13):
  print("안녕")
# Out:
# 안녕
# 안녕
# 안녕

# %%
# 문제 (2)
for i in range(0, 9, 3):
  print("안녕")
# Out:
# 안녕
# 안녕
# 안녕

# %%
# 문제 (3)
for i in range(-9, -15, -2):
  print("안녕")
# Out:
# 안녕
# 안녕
# 안녕
