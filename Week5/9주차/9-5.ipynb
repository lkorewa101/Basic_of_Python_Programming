# %% [markdown]
# 21113038 고기현

# %%
# 문제 (1)
a = 3
while a > 0:
  print("안녕")
  a = a - 1
# Out:
# 안녕
# 안녕
# 안녕

# %%
# 문제 (2)
a = 3
while a < 6:
  print("안녕")
  a += 1
# Out:
# 안녕
# 안녕
# 안녕

# %%
# 문제 (3)
a = 3
while True:
  print("안녕")
  a -= 1
  if a == 0: break
# Out:
# 안녕
# 안녕
# 안녕

# %%
# 문제 (4)
a = 100
while True:
  print("안녕")
  a -= 10
  if a  == 70: break
# Out:
# 안녕
# 안녕
# 안녕
