# %% [markdown]
# 21113038 고기현

# %%
N = int(input("N 정수를 입력하시오: "))
count = 0
for i in range(N):
  num = int(input("정수를 입력하시오: "))
  if num%2 == 0:
    count = count + 1
print("짝수 정수의 총 갯수:", count)
# Out:
# N 정수를 입력하시오: 3
# 정수를 입력하시오: 2
# 정수를 입력하시오: 3
# 정수를 입력하시오: 6
# 짝수 정수의 총 갯수: 2
