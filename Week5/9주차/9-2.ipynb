# %% [markdown]
# 21113038 고기현

# %%
total = 0
for i in range(5):
  num = int(input("숫자를 입력하시오: "))
  total = total+num
avg = total / 5
print("총합:", total, "평균:", avg)
# Out:
# 숫자를 입력하시오: 1
# 숫자를 입력하시오: 2
# 숫자를 입력하시오: 3
# 숫자를 입력하시오: 4
# 숫자를 입력하시오: 5
# 총합: 15 평균: 3.0
