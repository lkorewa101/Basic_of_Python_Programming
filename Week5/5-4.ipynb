# %% [markdown]
# 21113038 고기현

# %%
#파이썬프로그래밍기초 5주차 언어청각치료학과 23107089 김다은

# %%
myDict = {"scores": [100,90,80], "names":("Kim","Hong","Lee")}
scoresList = myDict["scores"]
namesList = myDict["names"]
print("name = ", namesList[1], "==>", "score = ", scoresList[1])
# Out:
# name =  Hong ==> score =  90
