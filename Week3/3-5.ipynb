# %% [markdown]
# 21113038 고기현

# %%
"I learned {0} in {1} for {2} days ".format("Python", "Korea", 3)
# Out:
# 'I learned Python in Korea for 3 days '

# %%
"{0:8.4f}".format(1.414325432)
# Out:
# '  1.4143'
