# %% [markdown]
# 21113038 고기현

# %%
myStr = "Hello, Hello"
myStr. upper()
# Out:
# 'HELLO, HELLO'

# %%
myStr. lower()
# Out:
# 'hello, hello'

# %%
myStr1 = "         Hello Python           "
myStr2 = myStr1. strip()
print(myStr2, "Everyone")
# Out:
# Hello Python Everyone

# %%
myStr3 = "Hello Python"
myStr3. find("Python")
# Out:
# 6

# %%
myStr3. index("Python")
# Out:
# 6
