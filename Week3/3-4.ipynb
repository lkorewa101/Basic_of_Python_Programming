# %% [markdown]
# 21113038 고기현

# %%
myStr = "Python Java C++ Prolog"

# %%
print(myStr.replace(' ',","))
# Out:
# Python,Java,C++,Prolog

# %%
print(myStr.replace(' ',"/"))
# Out:
# Python/Java/C++/Prolog

# %%
print(myStr.replace(' ',"-"))
# Out:
# Python-Java-C++-Prolog
