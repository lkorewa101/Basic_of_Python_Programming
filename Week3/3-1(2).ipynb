# %% [markdown]
# 21113038 고기현

# %%
myList = "We all love Python programming!"

# %%
myList[-1]
# Out:
# '!'

# %%
myList[:-20]
# Out:
# 'We all love'

# %%
myList[-24:]
# Out:
# 'love Python programming!'

# %%
myList[-19:-13]
# Out:
# 'Python'
