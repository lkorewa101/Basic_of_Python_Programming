# %% [markdown]
# 21113038 고기현

# %%
myStr = "We all love Python programming!"

# %%
myStr[30]
# Out:
# '!'

# %%
myStr[0:11]
# Out:
# 'We all love'

# %%
myStr[7:30]
# Out:
# 'love Python programming'

# %%
myStr[12:19]
# Out:
# 'Python '
