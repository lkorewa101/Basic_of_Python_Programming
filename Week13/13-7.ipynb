# %% [markdown]
# 21113038 고기현

# %%
with open('info.csv', 'r') as data_file:
  for line in data_file:
    name, weight, height = line.strip().split(',')
    # Error 처리: 데이터가 없으면 다음 반복문으로 넘어감
    if (not name) or (not weight) or (not height):
      continue

    bmi = float(weight) / ((float(height)/100) ** 2)
    result = ''

    if 25 <= bmi:
      result = '과체중'
    elif 18.5 <= bmi:
      result = '정상 체중'
    else:
      result = '저체중'

    output = '\n'.join([f'이름: {name}', f'몸무게: {weight}', f'키: {height}', f'BMI: {bmi:.1f}', f'결과: {result}'])
    print('-'*40, '\n', output)
# Out:
# ----------------------------------------
#  이름: 정라마
# 몸무게:  61.173880
# 키:  158.7
# BMI: 24.3
# 결과: 정상 체중
# ----------------------------------------
#  이름: 황다차
# 몸무게:  49.180569
# 키:  140.2
# BMI: 25.0
# 결과: 과체중
# ----------------------------------------
#  이름: 최자아
# 몸무게:  73.192221
# 키:  173.4
# BMI: 24.3
# 결과: 정상 체중
# ----------------------------------------
#  이름: 한다카
# 몸무게:  66.576337
# 키:  175.4
# BMI: 21.6
# 결과: 정상 체중
# ----------------------------------------
#  이름: 이파다
# 몸무게:  76.710919
# 키:  168.9
# BMI: 26.9
# 결과: 과체중
# ----------------------------------------
#  이름: 한자자
# 몸무게:  75.438911
# 키:  124.8
# BMI: 48.4
# 결과: 과체중
# ----------------------------------------
#  이름: 송바바
# 몸무게:  80.080198
# 키:  149.2
# BMI: 36.0
# 결과: 과체중
# ----------------------------------------
#  이름: 강자마
# 몸무게:  51.513765
# 키:  144.9
# BMI: 24.5
# 결과: 정상 체중
# ----------------------------------------
#  이름: 진하다
# 몸무게:  55.873818
# 키:  154.5
# BMI: 23.4
# 결과: 정상 체중
# ----------------------------------------
#  이름: 권카마
# 몸무게:  55.405070
# 키:  152.2
# BMI: 23.9
# 결과: 정상 체중
