# %% [markdown]
# 21113038 고기현

# %%
data = [-3, 2, 0, 4, -1, 0]

# map
print(list(map(lambda x: x + 2, data)))

#filter
print(list(filter(lambda x: x < 0, data)))
# Out:
# [-1, 4, 2, 6, 1, 2]
# [-3, -1]
