# %% [markdown]
# 21113038 고기현

# %%
# 매개변수로 받은 함수를 5번 호출하는 함수
def call_5_times(func):
  for i in range(5):
    func()

# 함수 정의
def print_star():
  print('*')

# 함수를 매개변수로 전달
call_5_times(print_star)

# 람다를 매개변수로 전달
call_5_times(lambda : print('*'))
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
