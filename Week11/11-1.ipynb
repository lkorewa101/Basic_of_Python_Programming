# %% [markdown]
# 21113038 고기현

# %%
def print_n_times(n):
  for _ in range(n):
    print('Hi')

# %%
# Call function with default parameters
print_n_times(10)
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
