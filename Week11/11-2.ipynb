# %% [markdown]
# 21113038 고기현

# %%
def print_n_times2(n, *messages):
  for _ in range(n):
    for message in messages:
      print(message, end=" ")

    print()

print_n_times2(5, "Hi", "Python", "Bye", ".")
# Out:
# Hi Python Bye .
# Hi Python Bye .
# Hi Python Bye .
# Hi Python Bye .
# Hi Python Bye .
