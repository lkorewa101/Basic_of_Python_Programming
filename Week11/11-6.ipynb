# %% [markdown]
# 21113038 고기현

# %%
def odd(*values):
  odd_list = []
  for i in values:
    if i % 2 == 1:
      odd_list.append(i)
  return odd_list
print(odd(4, 5, 7, 9, 10, 11, 12, 16, 19))
# Out:
# [5, 7, 9, 11, 19]
